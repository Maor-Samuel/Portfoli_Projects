# %% [markdown]
# Maor Samuel Project :
#
# i have picked to work on motorcycles database ,  for me it's a very interesting topic as a rider myself .
#
# the columns of the database are:
# 1. Brand - brand name of the motorcycle
# 2. Model - model name of the motorcycle
# 3. Year - year the motorcycle was built
# 4. Category - sub-class the motorcycle belongs to in the market (style of motorcycle)
# 5. Rating - review average out of 5 stars
# 6. Displacement (ccm) - engine size of the motorcycle in cubic centimeters (ccm)
# 7. Power (hp) - max power output in horsepower (hp) and kilowatt (kW) along with peak power rpm
# 8. Torque (Nm) - max torque in newton-meters (Nm) and foot-pounds (ft-lbs) along with peak torque rpm
# 9. Engine cylinder - number of cylinders in the engine as well as configuration
# 10. Engine stroke - number of stages to complete one power stroke of the engine
# 11. Gearbox - number of gears in transmission
# 12. Bore (mm) - diameter of each cylinder in millimeters (mm) and inches (in)
# 13. Stroke (mm) - distance within the cylinder a piston travels in millimeters (mm) and inches (in)
# 14. Transmission type - type of transmission of the motorcycle
# 15. Front brakes - type of front brake
# 16. Rear brakes - type of rear brake
# 17. Front tire - front tire size
# 18. Rear tire - rear tire size
# 19. Front suspension - front suspension type and configuration
# 20. Rear suspension - rear suspension type and configuration
# 21. Dry weight (kg) - weight of the motorcycle, without any fluids, in kilograms (kg) and pounds (lbs)
# 22. Wheelbase (mm) - distance between the points where the front and rear wheels touch the ground in millimeters (mm)
# 23. Fuel capacity (lts) - maximum capacity of fuel tank in liters (lts)
# 24. Fuel system - fuel delivery system into engine
# 25. Fuel control - valve configuration fo the engine
# 26. Seat height (mm) - height from bottom of seat to the ground in millimeters (mm)
# 27. Cooling system - engine cooling system
# 28. Color options - different color options of the motorcycle model for that particular year
# dtypes: float64(9), int64(1), object(18)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
moto = pd.read_csv(r'C:\Users\Samue\AppData\Local\Programs\Python\Python312\Python-Guide-Sima\Python Project - Maor Samuel - Motorcycle\motorcycle_list.csv')
# Out:
# C:\Users\Samue\AppData\Local\Temp\ipykernel_23932\2182554382.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   moto = pd.read_csv(r'C:\Users\Samue\AppData\Local\Programs\Python\Python312\Python-Guide-Sima\Python Project - Maor Samuel - Motorcycle\motorcycle_list.csv')

# %%
moto.tail(60)
# Out:
#          Brand                          Model  Year  \
# 38412  zündapp                   ks 125 sport  1975
# 38413  zündapp                   ks 125 sport  1976
# 38414  zündapp                   ks 125 sport  1977
# 38415  zündapp                         ks 175  1976
# 38416  zündapp                         ks 175  1977
# 38417  zündapp                         ks 175  1978
# 38418  zündapp                         ks 175  1979
# 38419  zündapp                         ks 175  1980
# 38420  zündapp                         ks 175  1981
# 38421  zündapp                         ks 175  1982
# 38422  zündapp                         ks 350  1976
# 38423  zündapp  ks 50 super sport type 517-20  1971
# 38424  zündapp            ks 500 kardan sport  1936
# 38425  zündapp            ks 500 kardan sport  1937
# 38426  zündapp            ks 500 kardan sport  1938
# 38427  zündapp            ks 500 kardan sport  1939
# 38428  zündapp                         ks 601  1950
# ...

# %% [markdown]
# ^^^^as we can see above the datebase has alot of Nulls , we will see next what columns we should DROP and what we need to CHANGE/PUT THE AVG/...../..^^^^

# %%
moto.describe()
# Out:
#                Year        Rating  Displacement (ccm)    Power (hp)  \
# count  38472.000000  21788.000000        37461.000000  26110.000000
# mean    2003.195883      3.401574          552.515072     50.776040
# std       20.083372      0.355631          545.394956     52.082094
# min     1894.000000      1.400000           25.000000      0.300000
# 25%     2000.000000      3.200000          125.000000     12.000000
# 50%     2010.000000      3.400000          397.200000     30.000000
# 75%     2016.000000      3.700000          805.000000     77.000000
# max     2022.000000      4.600000         8277.000000    804.000000
#
#         Torque (Nm)     Bore (mm)  Fuel capacity (lts)  Dry weight (kg)  \
# count  16634.000000  28689.000000         31704.000000     22483.000000
# mean      64.527173     72.596713            13.286191       164.151532
# std       63.884654     18.758621             6.010670        85.085133
# ...

# %%
moto.describe(include = 'all')
# Out:
#          Brand         Model          Year Category        Rating  \
# count    38472         38444  38472.000000    38472  21788.000000
# unique     576         17731           NaN       18           NaN
# top     yamaha  servi-car ge           NaN  Scooter           NaN
# freq      3414            38           NaN     6669           NaN
# mean       NaN           NaN   2003.195883      NaN      3.401574
# std        NaN           NaN     20.083372      NaN      0.355631
# min        NaN           NaN   1894.000000      NaN      1.400000
# 25%        NaN           NaN   2000.000000      NaN      3.200000
# 50%        NaN           NaN   2010.000000      NaN      3.400000
# 75%        NaN           NaN   2016.000000      NaN      3.700000
# max        NaN           NaN   2022.000000      NaN      4.600000
#
#         Displacement (ccm)    Power (hp)   Torque (Nm)  Engine cylinder  \
# count         37461.000000  26110.000000  16634.000000            38461
# ...

# %%
moto.drop_duplicates()
# Out:
#          Brand                Model  Year                   Category  Rating  \
# 0      acabion      da vinci 650-vi  2011  Prototype / concept model     3.2
# 1      acabion              gtbo 55  2007                      Sport     2.6
# 2      acabion  gtbo 600 daytona-vi  2011  Prototype / concept model     3.5
# 3      acabion  gtbo 600 daytona-vi  2021  Prototype / concept model     NaN
# 4      acabion              gtbo 70  2007  Prototype / concept model     3.1
# ...        ...                  ...   ...                        ...     ...
# 38467  zündapp                 z 22  1924                      Sport     NaN
# 38468  zündapp                z 249  1923                      Sport     NaN
# 38469  zündapp                z 249  1924                      Sport     NaN
# 38470  zündapp                z 300  1928                      Sport     NaN
# 38471  zündapp                z 300  1929                      Sport     NaN
#
# ...

# %% [markdown]
# ^^^^as you can see above ,i have tried to drop duplicates and still and up with 38472 rows x 28 columns, that means the datebase is clean of duplicates.^^^^|

# %%
moto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38472 entries, 0 to 38471
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                38472 non-null  object
#  1   Model                38444 non-null  object
#  2   Year                 38472 non-null  int64
#  3   Category             38472 non-null  object
#  4   Rating               21788 non-null  float64
#  5   Displacement (ccm)   37461 non-null  float64
#  6   Power (hp)           26110 non-null  float64
#  7   Torque (Nm)          16634 non-null  float64
#  8   Engine cylinder      38461 non-null  object
#  9   Engine stroke        38461 non-null  object
#  10  Gearbox              32675 non-null  object
#  11  Bore (mm)            28689 non-null  float64
#  12  Stroke (mm)          28689 non-null  object
#  13  Fuel capacity (lts)  31704 non-null  float64
#  14  Fuel system          27844 non-null  object
# ...

# %% [markdown]
# as we can see above from 38472 entries alot columns has nulls:
# 1. Rating column has 21788 entries out of 38472 ,
# 2. Power column has 26110 entries out of 38472 ,
# 3. Torque column has 16634 entries out of 38472 ,
# 4. Fuel column system has 27844 entries out of 38472 ,
# 5. Fuel control column has 22008 entries out of 38472 and so on.... that why we have to clean the database and drop uneeded columns.

# %%
moto = moto.drop(columns = 'Color options')

# %% [markdown]
# i have removed 'color options' columns because i dont need it for my work

# %%
moto = moto.drop(columns = 'Torque (Nm)')

# %% [markdown]
# i dont need the Torque column so i droped it

# %%
moto.dropna(subset = 'Power (hp)', inplace = True)

# %% [markdown]
# i have removed all the rows that have Null in Power(Horse Power) column, Horse Power is very basic information to know about motorcycle and
# To calculate horsepower, there are different formulas depending on the context.
# so it will be waste of time to keep the ones witout horse power.

# %%
moto.columns = moto.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# i have replaced column names to lowercase and replaced spaces with underscores so it will easier to workn on the database.

# %%
moto.head()
# Out:
#      brand                model  year                   category  rating  \
# 0  acabion      da vinci 650-vi  2011  Prototype / concept model     3.2
# 1  acabion              gtbo 55  2007                      Sport     2.6
# 2  acabion  gtbo 600 daytona-vi  2011  Prototype / concept model     3.5
# 3  acabion  gtbo 600 daytona-vi  2021  Prototype / concept model     NaN
# 4  acabion              gtbo 70  2007  Prototype / concept model     3.1
#
#    displacement_(ccm)  power_(hp) engine_cylinder engine_stroke  gearbox  ...  \
# 0                 NaN       804.0        Electric      Electric      NaN  ...
# 1              1300.0       541.0    In-line four   four-stroke  6-speed  ...
# 2                 NaN       536.0        Electric      Electric      NaN  ...
# 3                 NaN       536.0        Electric      Electric      NaN  ...
# 4              1300.0       689.0    In-line four   four-stroke  6-speed  ...
#
# ...

# %%
numeric_columns = [
    'displacement_(ccm)', 'power_(hp)', 'dry_weight_(kg)', 
    'wheelbase_(mm)', 'seat_height_(mm)'
]

for column in numeric_columns:
    moto[column] = pd.to_numeric(moto[column], errors='coerce')
    
    
    if moto[column].isna().sum() > 0:
        moto[column].fillna(moto[column].median(), inplace=True)
# Out:
# C:\Users\Samue\AppData\Local\Temp\ipykernel_23932\3182546197.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   moto[column].fillna(moto[column].median(), inplace=True)
# C:\Users\Samue\AppData\Local\Temp\ipykernel_23932\3182546197.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# i have alot of null even after i removed the ones witout horsepower ,so i had to fill them with median of that column :
# first Convert columns with numeric values that might be mixed with strings to appropriate numeric types
#  We'll use `pd.to_numeric` with errors='coerce' to handle non-numeric values .
#
#  then the for loop will Convert column to numeric, setting errors='coerce' to handle any non-numeric values.
#
#  and last If there are any missing values, fill them with the median of the column.

# %%
moto.head(60)
# Out:
#       brand                     model  year                   category  \
# 0   acabion           da vinci 650-vi  2011  Prototype / concept model
# 1   acabion                   gtbo 55  2007                      Sport
# 2   acabion       gtbo 600 daytona-vi  2011  Prototype / concept model
# 3   acabion       gtbo 600 daytona-vi  2021  Prototype / concept model
# 4   acabion                   gtbo 70  2007  Prototype / concept model
# 5    access      37 offroad e-scooter  2021                    Scooter
# 6    access       ams 3.20 supercross  2016                        ATV
# 7    access    ams 4.30 supermoto efi  2016                        ATV
# 8    access    ams 4.38 sm gear shift  2016                        ATV
# 9    access    ams 4.38 sx gear shift  2016                        ATV
# 10   access            ams 6.46 basic  2016                        ATV
# 11   access              ams 6.46 lux  2016                        ATV
# ...

# %%
moto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26110 entries, 0 to 38471
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   brand                26110 non-null  object
#  1   model                26096 non-null  object
#  2   year                 26110 non-null  int64
#  3   category             26110 non-null  object
#  4   rating               14892 non-null  float64
#  5   displacement_(ccm)   26110 non-null  float64
#  6   power_(hp)           26110 non-null  float64
#  7   engine_cylinder      26102 non-null  object
#  8   engine_stroke        26102 non-null  object
#  9   gearbox              22299 non-null  object
#  10  bore_(mm)            19272 non-null  float64
#  11  stroke_(mm)          19272 non-null  object
#  12  fuel_capacity_(lts)  21681 non-null  float64
#  13  fuel_system          17083 non-null  object
#  14  fuel_control         15680 non-null  object
# ...

# %%
moto = moto.drop(columns = 'rear_suspension')

# %%
moto = moto.drop(columns = 'front_suspension')

# %%
moto = moto.drop(columns = 'rating')

# %% [markdown]
# i have removed 3 columns - rating , front_suspension , rear_suspension the columns were to dirty and used by string.
# and i didnt need the rating if it has only 15k out of 26k if ill do matplotlib 11k of them will be median and that not good at all.
#
# and now we can work on a much cleaner database ! :)

# %%
plt.figure(figsize=(10, 6))
sb.lineplot(data=moto, x="year", y="power_(hp)", marker="o", color="orange", linewidth=2)
plt.title("Trend of Power (hp) by Year", fontsize=16, fontweight="bold", color="darkblue")
plt.xlabel("Year", fontsize=14)
plt.ylabel("Power (hp)", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
sb.despine()
plt.show()

# %% [markdown]
# in the plot above im showing what happend with horse power over the years,
# as you can see over the years the average horse power has been going up from the early 90 till today ,
# there is a big drop around 2000-2005 so i researched online and found this from wikipedia:
# After the relatively mild 1990 recession ended in early 1991, the country hit a belated unemployment rate peak of 7.8% in mid-1992. Job growth was initially muted by large layoffs among defense related industries.[2] However, payrolls accelerated in 1992 and experienced robust growth through 2000.[3]
#
# Predictions that the bubble would burst emerged during the dot-com bubble in the late 1990s. Predictions about a future burst increased following the October 27, 1997 mini-crash, in the wake of the 1997 Asian financial crisis. This caused an uncertain economic climate during the first few months of 1998. However conditions improved, and the Federal Reserve raised interest rates six times between June 1999 and May 2000 in an effort to cool the economy to achieve a soft landing. The burst of the stock market bubble occurred in the form of the NASDAQ crash in March 2000. Growth in gross domestic product slowed considerably in the third quarter of 2000 to the lowest rate since a contraction in the first quarter of 1992.[4]
#
# this is the link for the full articel:https://en.wikipedia.org/wiki/Early_2000s_recession
#
# so the economi got hit hard those years and im pretty sure there are connected , no extra cash to spend only developing and making new motorcycle , less transfering and transporting of materials , when you try to keep your head above the water you dont have time to extra think as we all know :)
#
#
# thats from the end of that articel:
# The Labor Department estimates that a net 1.735 million jobs were shed in 2001, with an additional net 508,000 lost during 2002. 2003 saw a small gain of a mere 105,000 jobs. Unemployment rose from 4.2% in February 2001 to 5.5% in November 2001, but did not peak until June 2003 at 6.3%, after which it declined to 5% by mid-2005.
#
# that only make my point stronger.

# %%
numeric_data = moto.select_dtypes(include=['float64', 'int64'])
# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(14, 10))
sb.heatmap(correlation_matrix, 
           annot=True, 
           fmt=".2f", 
           cmap="Spectral",  
           linewidths=1.5,   
           linecolor='black', 
           cbar_kws={'label': 'Correlation Coefficient'}, 
           annot_kws={"size": 12, "weight": "bold", "color": "black", 
                      "bbox": dict(boxstyle="round,pad=0.3", facecolor="white", edgecolor="0.3")})

plt.title(" Correlation Heatmap of Motorcycle Specifications", fontsize=18, fontweight="bold", color="darkred")
plt.show()

# %% [markdown]
# the plot above is Correlation Heatmap of moto database.
# as we can see above:
# 1.power and displacement are very connected (0.80), displacement measures the amount of space that the engine's pistons sweep within one stroke. More displacement can mean a more powerful engine
#
# 2.bore and displacement are connected to (0.77) ,  engine's bore is the diameter of each cylinder, while the stroke is the distance within the cylinder the piston travels. Basically, an engine's maximum power depends on how many rpm it can produce. The more rpm, the more power strokes, the more power it produces overall.
#
# 3.fuel capacity and displacement are connected(0.64), that mean's you need a bigger fuel tank if the displacmenet is higher ,what make the motorcycle more heavey , and you make it more heavey by adding fuel you need to make sure that rasing the displacement is worth it.
#
# 4.dry weight and displacement are connected (0.63) , that mean's if you raise the displacement the motorcycle will be heaveir , you need to use a stronger material(and most of the time it will be a heavier material,like part that made from aluminum will made from iron) so it will hold all that pressure and power its making, you need bigger fuel tank because it will burn more fuel.
#
# 5.wheel base and displacement are connected (0.57), so the more displacement and power a motorcycle have the bigger the wheel should have , but if the wheel is bigger the turn radius is bigger and thats not good at all, thats why you need to think good befor you raise the wheel base.
#
# 6.power and fuel capacity are connected(0.62) , the more power we have the more fuel it will burn as we said befor.
#
# 7.power and bore are connected(0.60), the bigger the bore the bigger the power .
#
#
# so as we can see displacement and bore are a very importent part of making a motorcycle and will determent the engine ways of work , the weight of the motorycle , what material it made from and alot more , even how to motorycle looks!

# %%
# Set theme and color palette
sb.set_theme(style="whitegrid")
palette = sb.color_palette("viridis", n_colors=len(moto['category'].unique()))
# Create the figure and count plot
plt.figure(figsize=(14, 8))
plot = sb.countplot(data=moto, y="category", order=moto['category'].value_counts().index, 
                    palette=palette, edgecolor="black", hue="category", legend=False)
plt.title("Count of Motorcycles by Category", fontsize=20, fontweight="bold", color="navy")
plt.xlabel("Count", fontsize=16, color="gray")
plt.ylabel("Category", fontsize=16, color="gray")
plt.xticks(fontsize=12, color="dimgray")
plt.yticks(fontsize=12, color="dimgray")
# Add gridlines
plt.grid(True, axis="x", linestyle="--", alpha=0.5)
# Add count labels on each bar
for bar in plot.patches:
    plt.text(
        bar.get_width() + 0.2,  # Position to the right of the bar
        bar.get_y() + bar.get_height() / 2,  # Center vertically on the bar
        f'{int(bar.get_width())}',  # Display the count as an integer
        ha='left', va='center', fontsize=12, color='black', fontweight='bold'
    )
sb.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# the plot above show for every category the number of motorcycle it have.
#
# first place we can see clearly that scooters are the king of the roads with 4690 kinds,
# for few reasons:
# 1.its small and cheap and easy to make.
# 2.you can ride one at a very young age.
# 3.the fact the are smaller and there tires are small that make them perfect for every day use in town, the meanuver much faster and can go easly between cars , the fuel eco is amazing for scooter you can save alot of cash using one for every day use.
# 4.with our modern technology scooter today can ride higeways and much stronger the older times.
#
#
# second place we have the sport bike , that have 4424 kinds , and that why:
# 1.every person look at every sport motorcycle no matter there size and its looks amazing and unique to them, children and adult the same there is somting different about sport motorcycle that shiny above all the other categorys.
# 2.there are the most powerful motorcycle from all the categorys, like exaple Yamaha mt 10 has 158.2 hp for a 210 kilogram of a motorcycle and that insane.
#
#
# third place we have the naked motorcycles (like sport motorcycle but with less faring , last covers so you can see more off the motocycle engine) that have 2893 kinds :
# 1.like the sport motorcycle the mostly have the same engine of the sport motorcycle but with less plastic covers on that make them cheaper, and forme that the best looking bikes! looking at the engine of that masterpiece is just food for the eye for me.
# 2.the problem with less plastic covers is more air hiting you and less fun as compltable ride , that why its so low compared to the sport bikes.
#
# and we have the mix of allaround,custome/cruiser , enduro/offroad:
# those categorys are the all doing motorycles:
# 1.cruisers have lower sitting ride , much more comfortable sit and sitting position
# 2.allaround can do as its says .ride the roads , side roads , and offroad
# 3.anduro/offroad are mtorcycle that made mostly to use offroad , thats why most off them cant be riden on road you will we get a ticket for that.
#
#
# so from what we can see people like scooters and sport bikes much more from the other categorys for the reason i have said above . :)

# %%
# 1. Violin Plot of Dry Weight by Category
plt.figure(figsize=(12, 6))
sb.violinplot(data=moto, x="Category", y="Dry weight (kg)",hue="Category", palette="coolwarm")
plt.title("Dry Weight Distribution by Motorcycle Category", fontsize=20, fontweight="bold")
plt.xlabel("Category", fontsize=14)
plt.ylabel("Dry Weight (kg)", fontsize=14)
plt.xticks(rotation=90 ,fontsize=10)
plt.grid(True, axis='y', linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# violin plot of dry weight by category above , that what i get from the plot:
# 1.as we can see the average dry wieght of scooters is around 100 k"g , like it the Count of Motorcycles by Category plot make the a very lightwieght motorcycle for everyday use.
#
# 2.Prototype / concept model - we can see that the sit all around but the average of them is around 180 k"g and that make sense beacuse the are testing and trying to improve and lower the wieght all the time lower wieght , means faster motorcycle .
#
# 3.sport average dry weight is around 150+ k"g and most over them is sitting around them 180 k"g, make them somwhat light weight compared to sport touring or touring motorycles , sport bikes have to be strong but light weight is possible because there job is to go faster as possbile,
# the top speed for sport bike lets say Yamaha mt 10 is 260 kmph   and a touring bike lets say Yamaha tigher 900 gt top speed is 202 kmph , the have se same engine but its tuned differently for there purpose
#
#
# so we can see that for every motorcycle category the weight is a very big deal , if a sport bike will be to light wieght it will we uncontrolable and if it will be to have it wont get to that top speed of a sport bike category , if a touring bike(as it say can go any road and tour around) will be to light it wont handle 2 riders and there bag they are touring around with very good, but if its to heavey they wont keep up the speed of other road motorcycle so they have to be light weight in so ways.
#
#
# so as we can see weight make a big impact on the motorcycle , different from cars that we talking abot tons - motorcycle is a small vehicle that can weight from 100 k"g to 400+ k"g and when you talk in that sizes a person weight can be as half of the motorycle!
# so companys will always try to find the best mix of weight for there motocycle and for every category its a diffrenet story.

# %%
# Calculate average power by engine cylinder type
avg_power = moto.groupby("engine_cylinder")["power_(hp)"].mean().reset_index()
# Set up the figure
plt.figure(figsize=(12, 6))
# Create the bar plot with hue set to the x variable and without a legend
sb.barplot(data=avg_power, x="engine_cylinder", y="power_(hp)", hue="engine_cylinder", 
           palette="viridis", edgecolor="black", dodge=False, legend=False)
plt.title("Average Power (hp) by Engine Cylinder Type", fontsize=20, fontweight="bold", color="navy")
plt.xlabel("Engine Cylinder Type", fontsize=13, color="gray")
plt.ylabel("Average Power (hp)", fontsize=13, color="gray")
plt.xticks(rotation=90, fontsize=10, color="dimgray")
plt.yticks(fontsize=12, color="dimgray")
# Add data labels on top of each bar
for index, row in avg_power.iterrows():
    plt.text(index, row["power_(hp)"] + 5, f'{row["power_(hp)"]:.1f}', 
             ha='center', va='bottom', fontsize=10, fontweight='bold', color="black")
plt.grid(True, axis='y', linestyle="--", alpha=0.5)
sb.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# the plot above Calculate average power by engine cylinder type , as we can see there are 3 that stand alot ,
# 1. the gas turbine with top of 346.3 hp (Clever name for Jet Engine) that work on gas its mostly will be much heaveir and much much more expensive , somting you ownt see on your every day.
# 2. v10 standing with 500 hp - A V10 engine is a ten-cylinder piston engine where two banks of five cylinders are arranged in a V configuration around a common crankshaft , so basically it has 10 cilnders that make it a very very heavey motorcycle to handel
# 3. and the v8 with 411.4 hp - the V8 is like the the V10 but with less cylinders
#
# so from what we see the more cylinders you add higher the horse power will be but the weight will be higher as well, yes we got a little fight with the v2 and v3 engine but that all about the tuning of the engine , from there on you can clearly see how every cyinder that add up , the horse power did got up and dramaticly.

# %% [markdown]
# in conclusion motorycle is a very different machine then a car , all the caculations are different and every little thing will determine how to motorycle will operate.
# but the weight and the horse power are the most importent part of the motorcycle.
